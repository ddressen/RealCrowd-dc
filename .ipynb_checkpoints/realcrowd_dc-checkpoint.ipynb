# %% [markdown]
# ## Data Challenge: RealCrowd risk of loss model
#
#     1. Goals:
#         a) Synthesize and clean the CMBS data files into one usable database
#         b) Find a high correlating economic factor, e.g. cost of living, demographics, housing affordability, employment numbers, or other factors (Market inputs that could have an impact or predictor for real estate values)
#
#     2. Deliverables:
#         a) Written summary of results
#         b) Code as repo on github
#         c) Summary of challenges
#         d) Is making a risk model feasible?
#
#     3. Observations of data analysis:
#         a)
#
#     4. Conclusions:
#         a)

# %%
import pandas as pd

# %%
# Function for reading xlsx files

def makeDf(filepathway, sheet):

    '''Given a filepathway and sheet of an xlsx file, load that file's sheet into a dataframe'''
    
    xlsx = pd.ExcelFile(filepathway)
    dataframe = pd.read_excel(xlsx, sheet)
    
    return dataframe

# %%
file = '/Users/donalddressen/Desktop/realcrowd_dc/Annex A Data/Annex A Upload 4-16-15/CGCMT 2015-GC27 Annex A.xlsx'
sheet = 'Annex'

df = makeDf(file, sheet)

# %%
df.head()
# Out:
#   CGCMT 2015-GC27 Annex A            Unnamed: 1 Unnamed: 2  \
# 0                     NaN                   NaN        NaN
# 1                     NaN                   NaN        NaN
# 2                     NaN                   NaN        NaN
# 3          Control Number  Loan / Property Flag  Footnotes
# 4                       1                  Loan   8, 9, 10
#
#              Unnamed: 3  Unnamed: 4                    Unnamed: 5  \
# 0                   NaN         NaN                           NaN
# 1                   NaN         NaN                           NaN
# 2                   NaN         NaN                           NaN
# 3  Mortgage Loan Seller  Originator                 Property Name
# 4                  GSMC        GSMC  Kemper Lakes Business Center
#
#       Unnamed: 6     Unnamed: 7                  Unnamed: 8  Unnamed: 9  \
# 0            NaN            NaN                         NaN         NaN
# ...

# %% [markdown]
# ## Data Challenge: RealCrowd risk of loss model
#
#     1. Goals:
#         a) Synthesize and clean the CMBS data files into one usable database
#         b) Find a high correlating economic factor, e.g. cost of living, demographics, housing affordability, employment numbers, or other factors (Market inputs that could have an impact or predictor for real estate values)
#
#     2. Deliverables:
#         a) Written summary of results
#         b) Code as repo on github
#         c) Summary of challenges
#         d) Is making a risk model feasible?
#
#     3. Observations of data analysis:
#         a)
#
#     4. Conclusions:
#         a)
